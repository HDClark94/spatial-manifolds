# %%
import os
import glob
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix
import pynapple as nap
from spatial_manifolds.toroidal import *
from spatial_manifolds.behaviour_plots import *
from spatial_manifolds.data.binning import get_bin_config
from spatial_manifolds.mlencoding import *
from spatial_manifolds.circular_decoder import circular_decoder, cross_validate_decoder, cross_validate_decoder_time, circular_nanmean
from spatial_manifolds.data.curation import curate_clusters
from scipy.stats import zscore
from spatial_manifolds.util import gaussian_filter_nan
from spatial_manifolds.predictive_grid import compute_travel_projected, wrap_list
from spatial_manifolds.behaviour_plots import *
from spatial_manifolds.detect_grids import *
from spatial_manifolds.brainrender_helper import *

import warnings
warnings.filterwarnings('ignore')
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

fig_path = '/Users/harryclark/Documents/figs/FIGURE1/'
source_path = '/Users/harryclark/Downloads/COHORT12/'
locations = pd.read_csv('/Users/harryclark/Downloads/all_cluster_brain_locations_chris.csv')
locations['coord_SCs_x'] = locations['coord_SCs_x'] * -1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

def make_annotations(mouse, path=None):
    Mouse = f'M{mouse}'

    data_paths = [f"/Users/harryclark/Documents/brainrender/probe_data/{Mouse}_probe_locations_{a}.mat" for a in [1,2,3,4]]
    shank_offsets_SC = pd.read_csv('/Users/harryclark/Documents/brainrender/probe_data/shank_offsets.csv')
    clusters_df = pd.read_csv(f'/Users/harryclark/Documents/brainrender/probe_data/extremum_channel_locations_kilosort4_0.csv')
    clusters_df = clusters_df[clusters_df['mouse'] == mouse]
    shank_offsets_SC = shank_offsets_SC[shank_offsets_SC['mouse'] == mouse]
    clusters_df = reconstruct_shank_id(clusters_df, mouse)
    probes_locs = [read_probe_mat(data_path) for data_path in data_paths]
    adjusted_probes_locs_CCF = np.array([adjust_probe_locs(probe_locs) for probe_locs in probes_locs])
    adjusted_probe_locs_SC, adjusted_probe_locs_CCF = correct_for_left_side(adjusted_probes_locs_CCF)
    adjusted_probe_locs_SC, adjusted_probe_locs_CCF = adjust_to_shank_offsets(adjusted_probe_locs_SC, shank_offsets_SC)
    
    ymin = -300; ymax = 3000
    xmin = -200; xmax = 1000
    xs = np.arange(xmin, xmax, 1)
    ys = np.arange(ymin, ymax, 1)

    if os.path.exists(f"{path}/M{mouse}_annotations.npy"):
        # Load annotations and colors from disk
        annotations = np.load(f"{path}/M{mouse}_annotations.npy", allow_pickle=True)
        annotation_colors = np.load(f"{path}/M{mouse}_annotation_colors.npy", allow_pickle=True)
        return annotations, annotation_colors, xs, ys
    
    else:
        annotations = np.zeros((len(ys), len(xs)), dtype=object)
        for yi, y in enumerate(ys):
            for xi, x in enumerate(xs):
                coord_SC, coord_CCF  = brain_coord_from_xy(x, y, adjusted_probe_locs_SC, shank_id=0)
                z_CCF, y_CCF, x_CCF = np.round(coord_CCF/10).astype(int)
                annotation_index = annotations_set[z_CCF,y_CCF,x_CCF]
                if len(structure_set[structure_set['id'] == annotation_index]) ==1:
                    annotation = structure_set[structure_set['id'] == annotation_index]['acronym'].iloc[0]
                else:
                    annotation ='root' # out of brain
                annotations[yi,xi] = annotation

        annotation_colors = get_annotation_colors_2D(annotations)

        # Save
        np.save(f"{path}/M{mouse}_annotations.npy", annotations)
        np.save(f"{path}/M{mouse}_annotation_colors.npy", annotation_colors)

    return annotations, annotation_colors, xs, ys

# %%
data_dir = '/Users/harryclark/Downloads/COHORT12/medial_lateral_xgboost/'
all_files = glob.glob(os.path.join(data_dir, "*.pkl"))

data = pd.DataFrame()
for file in all_files:
    data = pd.concat([data, pd.read_pickle(file)], ignore_index=True)

# Merge coord_SCs_x from locations into data using mouse, day, and target_cluster_id as keys
data = pd.merge(
    data,
    locations[['mouse', 'day', 'cluster_id', 'coord_SCs_x']],
    how='left',
    left_on=['mouse', 'day', 'target_cluster_id'],
    right_on=['mouse', 'day', 'cluster_id']
 )

# %%
# Find good GC examples with both medial and lateral covariate_pos_label entries
# Group by mouse, day, target_cluster_id, and target_pos_label, and filter for those with both covariate_pos_labels

# Only consider GC cells in medial_MEC
gc_medial = data[
    (data['target_cell_type'] == 'GC') &
    (data['target_pos_label'] == 'medial_MEC') &
    (data['n_covariate_cells'] > 0) &
    (data['include_position'] == True)
]

# Group by mouse, day, cluster, and keep only those with both covariate_pos_labels
grouped = gc_medial.groupby(['mouse', 'day', 'target_cluster_id'])

good_examples = []
for (mouse, day, cluster_id), group in grouped:
    cov_labels = set(group['covariate_pos_label'])
    if {'medial_MEC', 'lateral_MEC'}.issubset(cov_labels):
        # For each covariate_pos_label, print n_covariate_cells
        for cov_label in ['medial_MEC', 'lateral_MEC']:
            n_cov = group[group['covariate_pos_label'] == cov_label]['n_covariate_cells'].values
            print(f"Mouse: {mouse}, Day: {day}, Cluster: {cluster_id}, Covariate: {cov_label}, n_covariate_cells: {n_cov[0] if len(n_cov) > 0 else 'NA'}")
        good_examples.append((mouse, day, cluster_id))

# Optionally, print a summary of how many good examples were found
print(f"Total good examples found: {len(good_examples)}")
# Out:
# Mouse: 20, Day: 16, Cluster: 152, Covariate: medial_MEC, n_covariate_cells: 59
# Mouse: 20, Day: 16, Cluster: 152, Covariate: lateral_MEC, n_covariate_cells: 95
# Mouse: 21, Day: 16, Cluster: 482, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 482, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 484, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 484, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 485, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 485, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 490, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 490, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 495, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 495, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 502, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 502, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 506, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 506, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 510, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 510, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 513, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 513, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 529, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 529, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 25, Day: 17, Cluster: 217, Covariate: medial_MEC, n_covariate_cells: 8
# Mouse: 25, Day: 17, Cluster: 217, Covariate: lateral_MEC, n_covariate_cells: 4
# Mouse: 25, Day: 18, Cluster: 322, Covariate: medial_MEC, n_covariate_cells: 40
# Mouse: 25, Day: 18, Cluster: 322, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 25, Day: 25, Cluster: 3, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 3, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 11, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 11, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 14, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 14, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 15, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 15, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 69, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 69, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 71, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 71, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 76, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 76, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 83, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 83, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 87, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 87, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 91, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 91, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 96, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 96, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 101, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 101, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 104, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 104, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 105, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 105, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 106, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 106, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 109, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 109, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 111, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 111, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 120, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 120, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 26, Day: 15, Cluster: 185, Covariate: medial_MEC, n_covariate_cells: 20
# Mouse: 26, Day: 15, Cluster: 185, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 26, Day: 15, Cluster: 186, Covariate: medial_MEC, n_covariate_cells: 20
# Mouse: 26, Day: 15, Cluster: 186, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 26, Day: 15, Cluster: 233, Covariate: medial_MEC, n_covariate_cells: 20
# Mouse: 26, Day: 15, Cluster: 233, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 26, Day: 15, Cluster: 267, Covariate: medial_MEC, n_covariate_cells: 20
# Mouse: 26, Day: 15, Cluster: 267, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 26, Day: 15, Cluster: 298, Covariate: medial_MEC, n_covariate_cells: 20
# Mouse: 26, Day: 15, Cluster: 298, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 26, Day: 19, Cluster: 24, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 24, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 113, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 113, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 114, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 114, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 115, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 115, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 123, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 123, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 124, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 124, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 126, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 126, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 132, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 132, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 133, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 133, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 145, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 145, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 149, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 149, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 155, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 155, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 156, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 156, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 163, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 163, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 166, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 166, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 179, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 179, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 183, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 183, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 185, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 185, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 195, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 195, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 201, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 201, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 203, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 203, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 217, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 217, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 221, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 221, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 224, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 224, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 227, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 227, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 28, Day: 17, Cluster: 70, Covariate: medial_MEC, n_covariate_cells: 42
# Mouse: 28, Day: 17, Cluster: 70, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 28, Day: 17, Cluster: 107, Covariate: medial_MEC, n_covariate_cells: 42
# Mouse: 28, Day: 17, Cluster: 107, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 28, Day: 17, Cluster: 148, Covariate: medial_MEC, n_covariate_cells: 42
# Mouse: 28, Day: 17, Cluster: 148, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 28, Day: 17, Cluster: 186, Covariate: medial_MEC, n_covariate_cells: 42
# Mouse: 28, Day: 17, Cluster: 186, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 28, Day: 23, Cluster: 115, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 115, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 23, Cluster: 138, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 138, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 23, Cluster: 141, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 141, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 23, Cluster: 149, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 149, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 23, Cluster: 152, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 152, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 23, Cluster: 154, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 154, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 25, Cluster: 99, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 99, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 108, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 108, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 126, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 126, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 139, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 139, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 140, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 140, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 147, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 147, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 149, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 149, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 151, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 151, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 153, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 153, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 154, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 154, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 155, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 155, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 156, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 156, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 158, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 158, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 160, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 160, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 162, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 162, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 174, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 174, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 177, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 177, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 188, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 188, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 242, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 242, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 258, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 258, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 284, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 284, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 287, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 287, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 29, Day: 16, Cluster: 167, Covariate: medial_MEC, n_covariate_cells: 8
# Mouse: 29, Day: 16, Cluster: 167, Covariate: lateral_MEC, n_covariate_cells: 26
# Mouse: 29, Day: 17, Cluster: 126, Covariate: medial_MEC, n_covariate_cells: 33
# Mouse: 29, Day: 17, Cluster: 126, Covariate: lateral_MEC, n_covariate_cells: 41
# Mouse: 29, Day: 17, Cluster: 132, Covariate: medial_MEC, n_covariate_cells: 33
# Mouse: 29, Day: 17, Cluster: 132, Covariate: lateral_MEC, n_covariate_cells: 41
# Mouse: 29, Day: 17, Cluster: 143, Covariate: medial_MEC, n_covariate_cells: 33
# Mouse: 29, Day: 17, Cluster: 143, Covariate: lateral_MEC, n_covariate_cells: 41
# Mouse: 29, Day: 17, Cluster: 148, Covariate: medial_MEC, n_covariate_cells: 33
# Mouse: 29, Day: 17, Cluster: 148, Covariate: lateral_MEC, n_covariate_cells: 41
# Mouse: 29, Day: 18, Cluster: 106, Covariate: medial_MEC, n_covariate_cells: 33
# Mouse: 29, Day: 18, Cluster: 106, Covariate: lateral_MEC, n_covariate_cells: 5
# Mouse: 29, Day: 23, Cluster: 132, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 132, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 160, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 160, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 184, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 184, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 191, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 191, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 194, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 194, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 202, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 202, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 213, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 213, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 214, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 214, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 216, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 216, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 217, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 217, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 219, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 219, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 25, Cluster: 47, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 47, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 336, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 336, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 368, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 368, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 370, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 370, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 376, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 376, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 377, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 377, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 385, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 385, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 387, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 387, Covariate: lateral_MEC, n_covariate_cells: 51
# Total good examples found: 118

# %%
good_mouse = 26
good_day = 19

# Find good GC examples with both medial and lateral covariate_pos_label entries
gc_medial = data[
    (data['target_cell_type'] == 'GC') &
    (data['target_pos_label'] == 'medial_MEC') &
    (data['n_covariate_cells'] > 0) &
    (data['include_position'] == True)
]

grouped = gc_medial.groupby(['mouse', 'day', 'target_cluster_id'])

good_examples = []
for (mouse, day, cluster_id), group in grouped:
    cov_labels = set(group['covariate_pos_label'])
    if {'medial_MEC', 'lateral_MEC'}.issubset(cov_labels):
        for cov_label in ['medial_MEC', 'lateral_MEC']:
            n_cov = group[group['covariate_pos_label'] == cov_label]['n_covariate_cells'].values
            print(f"Mouse: {mouse}, Day: {day}, Cluster: {cluster_id}, Covariate: {cov_label}, n_covariate_cells: {n_cov[0] if len(n_cov) > 0 else 'NA'}")
        good_examples.append((mouse, day, cluster_id))

filtered_good_examples = [(mouse, day, cluster_id) for (mouse, day, cluster_id) in good_examples if int(mouse) == good_mouse and int(day) == good_day]

print(f"Total good examples found: {len(good_examples)}")
# Out:
# Mouse: 20, Day: 16, Cluster: 152, Covariate: medial_MEC, n_covariate_cells: 59
# Mouse: 20, Day: 16, Cluster: 152, Covariate: lateral_MEC, n_covariate_cells: 95
# Mouse: 21, Day: 16, Cluster: 482, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 482, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 484, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 484, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 485, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 485, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 490, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 490, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 495, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 495, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 502, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 502, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 506, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 506, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 510, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 510, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 513, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 513, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 21, Day: 16, Cluster: 529, Covariate: medial_MEC, n_covariate_cells: 56
# Mouse: 21, Day: 16, Cluster: 529, Covariate: lateral_MEC, n_covariate_cells: 109
# Mouse: 25, Day: 17, Cluster: 217, Covariate: medial_MEC, n_covariate_cells: 8
# Mouse: 25, Day: 17, Cluster: 217, Covariate: lateral_MEC, n_covariate_cells: 4
# Mouse: 25, Day: 18, Cluster: 322, Covariate: medial_MEC, n_covariate_cells: 40
# Mouse: 25, Day: 18, Cluster: 322, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 25, Day: 25, Cluster: 3, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 3, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 11, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 11, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 14, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 14, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 15, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 15, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 69, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 69, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 71, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 71, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 76, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 76, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 83, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 83, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 87, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 87, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 91, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 91, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 96, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 96, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 101, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 101, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 104, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 104, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 105, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 105, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 106, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 106, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 109, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 109, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 111, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 111, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 25, Day: 25, Cluster: 120, Covariate: medial_MEC, n_covariate_cells: 9
# Mouse: 25, Day: 25, Cluster: 120, Covariate: lateral_MEC, n_covariate_cells: 31
# Mouse: 26, Day: 15, Cluster: 185, Covariate: medial_MEC, n_covariate_cells: 20
# Mouse: 26, Day: 15, Cluster: 185, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 26, Day: 15, Cluster: 186, Covariate: medial_MEC, n_covariate_cells: 20
# Mouse: 26, Day: 15, Cluster: 186, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 26, Day: 15, Cluster: 233, Covariate: medial_MEC, n_covariate_cells: 20
# Mouse: 26, Day: 15, Cluster: 233, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 26, Day: 15, Cluster: 267, Covariate: medial_MEC, n_covariate_cells: 20
# Mouse: 26, Day: 15, Cluster: 267, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 26, Day: 15, Cluster: 298, Covariate: medial_MEC, n_covariate_cells: 20
# Mouse: 26, Day: 15, Cluster: 298, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 26, Day: 19, Cluster: 24, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 24, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 113, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 113, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 114, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 114, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 115, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 115, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 123, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 123, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 124, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 124, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 126, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 126, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 132, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 132, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 133, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 133, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 145, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 145, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 149, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 149, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 155, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 155, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 156, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 156, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 163, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 163, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 166, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 166, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 179, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 179, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 183, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 183, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 185, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 185, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 195, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 195, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 201, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 201, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 203, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 203, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 217, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 217, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 221, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 221, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 224, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 224, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 26, Day: 19, Cluster: 227, Covariate: medial_MEC, n_covariate_cells: 54
# Mouse: 26, Day: 19, Cluster: 227, Covariate: lateral_MEC, n_covariate_cells: 147
# Mouse: 28, Day: 17, Cluster: 70, Covariate: medial_MEC, n_covariate_cells: 42
# Mouse: 28, Day: 17, Cluster: 70, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 28, Day: 17, Cluster: 107, Covariate: medial_MEC, n_covariate_cells: 42
# Mouse: 28, Day: 17, Cluster: 107, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 28, Day: 17, Cluster: 148, Covariate: medial_MEC, n_covariate_cells: 42
# Mouse: 28, Day: 17, Cluster: 148, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 28, Day: 17, Cluster: 186, Covariate: medial_MEC, n_covariate_cells: 42
# Mouse: 28, Day: 17, Cluster: 186, Covariate: lateral_MEC, n_covariate_cells: 13
# Mouse: 28, Day: 23, Cluster: 115, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 115, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 23, Cluster: 138, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 138, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 23, Cluster: 141, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 141, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 23, Cluster: 149, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 149, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 23, Cluster: 152, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 152, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 23, Cluster: 154, Covariate: medial_MEC, n_covariate_cells: 18
# Mouse: 28, Day: 23, Cluster: 154, Covariate: lateral_MEC, n_covariate_cells: 71
# Mouse: 28, Day: 25, Cluster: 99, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 99, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 108, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 108, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 126, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 126, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 139, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 139, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 140, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 140, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 147, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 147, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 149, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 149, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 151, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 151, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 153, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 153, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 154, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 154, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 155, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 155, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 156, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 156, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 158, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 158, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 160, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 160, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 162, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 162, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 174, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 174, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 177, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 177, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 188, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 188, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 242, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 242, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 258, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 258, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 284, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 284, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 28, Day: 25, Cluster: 287, Covariate: medial_MEC, n_covariate_cells: 26
# Mouse: 28, Day: 25, Cluster: 287, Covariate: lateral_MEC, n_covariate_cells: 32
# Mouse: 29, Day: 16, Cluster: 167, Covariate: medial_MEC, n_covariate_cells: 8
# Mouse: 29, Day: 16, Cluster: 167, Covariate: lateral_MEC, n_covariate_cells: 26
# Mouse: 29, Day: 17, Cluster: 126, Covariate: medial_MEC, n_covariate_cells: 33
# Mouse: 29, Day: 17, Cluster: 126, Covariate: lateral_MEC, n_covariate_cells: 41
# Mouse: 29, Day: 17, Cluster: 132, Covariate: medial_MEC, n_covariate_cells: 33
# Mouse: 29, Day: 17, Cluster: 132, Covariate: lateral_MEC, n_covariate_cells: 41
# Mouse: 29, Day: 17, Cluster: 143, Covariate: medial_MEC, n_covariate_cells: 33
# Mouse: 29, Day: 17, Cluster: 143, Covariate: lateral_MEC, n_covariate_cells: 41
# Mouse: 29, Day: 17, Cluster: 148, Covariate: medial_MEC, n_covariate_cells: 33
# Mouse: 29, Day: 17, Cluster: 148, Covariate: lateral_MEC, n_covariate_cells: 41
# Mouse: 29, Day: 18, Cluster: 106, Covariate: medial_MEC, n_covariate_cells: 33
# Mouse: 29, Day: 18, Cluster: 106, Covariate: lateral_MEC, n_covariate_cells: 5
# Mouse: 29, Day: 23, Cluster: 132, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 132, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 160, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 160, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 184, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 184, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 191, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 191, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 194, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 194, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 202, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 202, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 213, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 213, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 214, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 214, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 216, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 216, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 217, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 217, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 23, Cluster: 219, Covariate: medial_MEC, n_covariate_cells: 24
# Mouse: 29, Day: 23, Cluster: 219, Covariate: lateral_MEC, n_covariate_cells: 88
# Mouse: 29, Day: 25, Cluster: 47, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 47, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 336, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 336, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 368, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 368, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 370, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 370, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 376, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 376, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 377, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 377, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 385, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 385, Covariate: lateral_MEC, n_covariate_cells: 51
# Mouse: 29, Day: 25, Cluster: 387, Covariate: medial_MEC, n_covariate_cells: 48
# Mouse: 29, Day: 25, Cluster: 387, Covariate: lateral_MEC, n_covariate_cells: 51
# Total good examples found: 118

# %%
# For each good example cell, reconstruct firing rate profiles using xgboost predictions
# You will need to fill in the details for loading tcs_time, pos_in_time, and MLencoding setup

# set up xgboost history model
xgb_history = MLencoding(tunemodel='xgboost', cov_history=True, spike_history=False,
                            window=time_bs, n_filters=5, max_time=1000)

#filtered_good_examples = [(25,25,91), (25,25,235)]
for mouse, day, cluster_id in filtered_good_examples:
    print(f"\nMouse: {mouse}, Day: {day}, Cluster: {cluster_id}")
    gcs, ngs, ns, sc, ngs_ns, all = cell_classification_of1(mouse, day, percentile_threshold=95, verbose=False) # subset
    tcs, tcs_time, _, last_ephys_bin, beh, clusters = compute_vr_tcs(mouse,day, apply_zscore=False, apply_guassian_filter=False)
    last_ephys_time_bin = clusters[clusters.index[0]].count(bin_size=time_bs, time_units = 'ms').index[-1]

    # define y-limits for probe plots based on all probe_y values
    min_y = all['probe_y'].min() - 300
    max_y = all['probe_y'].max() + 300
    
    # time binned variables for later
    ep = nap.IntervalSet(start=0, end=last_ephys_time_bin, time_units = 's')
    speed_in_time = np.array(beh['S'].bin_average(bin_size=time_bs, time_units = 'ms', ep=ep))
    dt_in_time = np.array(beh['travel'].bin_average(bin_size=time_bs, time_units = 'ms', ep=ep)-((beh['trial_number'][0]-1)*tl))
    pos_in_time = dt_in_time%tl
    trial_number_in_time = (dt_in_time//tl)+beh['trial_number'][0]

    if np.any(np.isnan(pos_in_time)):
        series = pd.Series(dt_in_time)
        filled_series = series.ffill().bfill()
        dt_in_time = np.array(filled_series)
        pos_in_time = dt_in_time%tl
        trial_number_in_time = (dt_in_time//tl)+beh['trial_number'][0]

    if np.any(np.isnan(speed_in_time)):
        series = pd.Series(speed_in_time)
        filled_series = series.ffill().bfill()
        speed_in_time = np.array(filled_series)

    # Get the target cell's firing rate
    target_fr = tcs_time[cluster_id]

    locations = pd.read_csv(f'{source_path}/all_cluster_brain_locations_chris.csv')
    locations = locations[(locations['mouse'] == mouse) & (locations['day'] == day)]
    locations['coord_SCs_x'] = locations['coord_SCs_x'] * -1  # correct for the flipped SCs x coordinates

    # Set up 4-column plot: True, Pos-only, Medial, Lateral
    fig, ax = plt.subplots(ncols=4, nrows=3, figsize=(rm_figsize[0]*3.2, rm_figsize[1]*1.7), 
                           sharex=False, sharey='row', height_ratios=[0.6, 0.25, 1], width_ratios=[1,1,1,1])
    plt.subplots_adjust(wspace=0.38, hspace=0.35)

    # --- Annotation plot above Pos-only column (no cells highlighted) ---
    annotations, annotation_colors, xs, ys = make_annotations(mouse, path='/Users/harryclark/Documents/spatial-manifolds/data')
    unique_colors = np.unique(annotation_colors)
    for color_ in unique_colors:
        border_points = extract_border(annotation_colors, color_, only_border=False)
        x_points = xs[border_points[:, 1]]
        y_points = ys[border_points[:, 0]]
        ax[0,1].scatter(x_points, y_points, color=color_, s=1, label=color_, rasterized=True)
    plot_NP2_probe(ax[0,1], sorting_analyzer_path='/Users/harryclark/Downloads/kilosort4_sa', 
                probe_alpha=0.5, contacts_alpha=0.0, probe_color='grey', probe_edgecolor='black')
    ax[0,1].set_ylim([min_y, max_y])
    ax[0,1].set_xlim([-100, 900])
    ax[0,1].spines['top'].set_visible(True)
    ax[0,1].spines['right'].set_visible(True)
    ax[0,1].spines['bottom'].set_visible(True)
    ax[0,1].spines['left'].set_visible(True)

    # --- True rate map ---
    tc = tcs[cluster_id]
    tc = gaussian_filter(np.nan_to_num(tc).astype(np.float64), sigma=2.5)
    tc = tc[:last_ephys_bin] # only want bins with ephys data in it
    tcz = zscore(tc)
    print(f'plotting true rate map')
    plot_firing_rate_map(ax[2,0], tc, bs=bs, tl=tl, p=95, sort_indices=None, cmap=white_to_hex_cmap('#69201a'))
    ax[1,0].set_title('True', fontsize=5)

    # --- Position-only (n=0) reconstruction ---
    X_posonly = pos_in_time.reshape(-1, 1)
    Y_hat_pos, pR2_cv_pos = xgb_history.fit_cv(X_posonly, target_fr, verbose=0, continuous_folds=True)
    print(f'for cell {cluster_id}, avg pR2 (pos only) is {np.nanmean(pR2_cv_pos)}, using 0 covariate cells')
    expected_spikes_pos = {ns.cluster_id.values[0]: Y_hat_pos}
    tcs_expected_spikes_pos, _, _ , last_ephys_bin, beh, _ = compute_vr_tcs_using_expected_spikes(
        mouse, day, apply_zscore=False, apply_guassian_filter=False, vr_type='VR', source_path=source_path, expected_spikes=expected_spikes_pos)
    tc_es_pos = tcs_expected_spikes_pos[ns.cluster_id.values[0]]
    tc_es_pos = gaussian_filter(np.nan_to_num(tc_es_pos).astype(np.float64), sigma=2.5)
    tc_es_pos = tc_es_pos[:last_ephys_bin]
    plot_firing_rate_map(ax[2,1], tc_es_pos, bs=bs, tl=tl, p=95, sort_indices=None, cmap=white_to_hex_cmap('#69201a'))
    ax[1,1].set_title(f'Pos only (n=0)\npr²: {np.nanmean(pR2_cv_pos):.2f}', fontsize=5)

    # Plot average firing rate profile for Pos only
    trial_groups, trial_colors = get_trial_groups_and_colors(beh, last_ephys_bin, tl, bs, ignore_performance=True)
    for group in np.unique(trial_groups):
        if len(trial_groups[trial_groups == group]) > 5:
            x, y = get_avg_profile(tc_es_pos, bs, tl, mask=trial_groups==group)
            ax[1,1].plot(x, y, color=trial_colors[trial_groups==group][0], linewidth=1)
    # Only allow max two y ticks on 2nd row
    for col in range(4):
        ax[1,col].yaxis.set_major_locator(plt.MaxNLocator(nbins=2, integer=True))
    # Remove axis from 1st row, 2nd column only
    ax[0,1].axis('off')

    # --- Medial and Lateral reconstructions ---
    tidy_labels = {'medial_MEC': 'P + mNGS', 'lateral_MEC': 'P + lNGS'}
    for cov_idx, cov_label in enumerate(['medial_MEC', 'lateral_MEC']):
        # Get covariate NGS cluster_ids in the correct ML bin
        cov_bounds = (-np.inf, 3400) if cov_label == 'medial_MEC' else (3400, np.inf)
        covariate_cluster_ids = ngs.cluster_id.values.astype(int)
        covariate_cluster_ids = covariate_cluster_ids[
            np.isin(
                covariate_cluster_ids,
                locations[
                    (locations['coord_SCs_x'] >= cov_bounds[0]) &
                    (locations['coord_SCs_x'] < cov_bounds[1])
                ]['cluster_id'].values.astype(int)
            )
        ]

        # Build covariate matrix X (n_timepoints x n_covariate_cells)
        cov_tcs_time = {cid: tcs_time[cid] for cid in covariate_cluster_ids if cid in tcs_time}
        if len(cov_tcs_time) == 0:
            print(f"No covariate cells found for {cov_label}")
            continue
        X = np.vstack(list(cov_tcs_time.values())).T
        X = np.column_stack((pos_in_time, X))
        n_cov_cells = len(X.T)-1 # subtract 1 for position
        Y_hat, pR2_cv = xgb_history.fit_cv(X, target_fr, verbose=0, continuous_folds=True)
        print(f'for cell {cluster_id}, avg pR2 is {np.nanmean(pR2_cv)}, for {cov_label}, using {n_cov_cells} covariate cells')
        expected_spikes = {ns.cluster_id.values[0]: Y_hat}
        tcs_expected_spikes, _, _ , last_ephys_bin, beh, _ = compute_vr_tcs_using_expected_spikes(
            mouse, day, apply_zscore=False, apply_guassian_filter=False, vr_type='VR', source_path=source_path, expected_spikes=expected_spikes)
        tc_es = tcs_expected_spikes[ns.cluster_id.values[0]]
        tc_es = gaussian_filter(np.nan_to_num(tc_es).astype(np.float64), sigma=2.5)
        tc_es = tc_es[:last_ephys_bin]
        plot_firing_rate_map(ax[2,cov_idx+2], tc_es, bs=bs, tl=tl, p=95, sort_indices=None, cmap=white_to_hex_cmap('#69201a'))
        ax[1,cov_idx+2].set_title(f'{tidy_labels[cov_label]} (n={n_cov_cells})\npr²: {np.nanmean(pR2_cv):.2f}', fontsize=5)

        # Plot trial-averaged profiles for each group
        for group in np.unique(trial_groups):
            if len(trial_groups[trial_groups == group]) > 5:
                x, y = get_avg_profile(tc, bs, tl, mask=trial_groups==group)
                if cov_idx == 0:
                    ax[1,0].plot(x, y, color=trial_colors[trial_groups==group][0], linewidth=1)
                x, y = get_avg_profile(tc_es, bs, tl, mask=trial_groups==group)
                ax[1,cov_idx+2].plot(x, y, color=trial_colors[trial_groups==group][0], linewidth=1)

        # Plot probe locations and cell highlights for each covariate column
        annotations, annotation_colors, xs, ys = make_annotations(mouse, path='/Users/harryclark/Documents/spatial-manifolds/data')
        unique_colors = np.unique(annotation_colors)
        for color_ in unique_colors:
            border_points = extract_border(annotation_colors, color_, only_border=False)
            x_points = xs[border_points[:, 1]]
            y_points = ys[border_points[:, 0]]
            ax[0,cov_idx+2].scatter(x_points, y_points, color=color_, s=1, label=color_, rasterized=True)
        plot_NP2_probe(ax[0,cov_idx+2], sorting_analyzer_path='/Users/harryclark/Downloads/kilosort4_sa', 
                    probe_alpha=0.5, contacts_alpha=0.0, probe_color='grey', probe_edgecolor='black')
        ax[0,cov_idx+2].scatter(ngs.probe_x.values, ngs.probe_y.values, marker='o', color="grey", alpha=0.4, s=7)
        ax[0,cov_idx+2].scatter(gcs.probe_x.values, gcs.probe_y.values, marker='o', color="grey", alpha=0.4, s=7)
        min_y = min(all['probe_y'].values) - 300
        max_y = max(all['probe_y'].values) + 300
        target_id = cluster_id
        target_row = all[all['cluster_id'] == target_id]
        # Move star scatter after all other scatter points for highest zorder
        if not target_row.empty:
            x_t, y_t = target_row['probe_x'].values[0], target_row['probe_y'].values[0]
            ax[0,cov_idx+2].scatter(x_t, y_t, marker='*', s=120, color='white', edgecolor='black', linewidth=0.7, zorder=100)
        cov_row = all[np.isin(all['cluster_id'], covariate_cluster_ids)]
        if not cov_row.empty:
            for _, row in cov_row.iterrows():
                x_c, y_c = row['probe_x'], row['probe_y']
                from matplotlib.patches import Circle
                circ2 = Circle((x_c, y_c), radius=20, edgecolor='#0d2958', facecolor='#0d2958', lw=2, alpha=0.6, zorder=12)
                ax[0,cov_idx+2].add_patch(circ2)
        ax[0,cov_idx+2].set_ylim([min_y, max_y])
        ax[0,cov_idx+2].set_xlim([-100, 900])
        ax[0,cov_idx+2].spines['top'].set_visible(True)
        ax[0,cov_idx+2].spines['right'].set_visible(True)
        ax[0,cov_idx+2].spines['bottom'].set_visible(True)
        ax[0,cov_idx+2].spines['left'].set_visible(True)

    # Set axis labels and hide unused axes
    ax[2,0].set_xlabel('Pos (cm)')
    ax[2,1].set_xlabel('Pos (cm)')
    ax[2,2].set_xlabel('Pos (cm)')
    ax[2,3].set_xlabel('Pos (cm)')
    # Only show y tick labels on the 3rd row, 1st column
    ax[2,1].set_yticklabels([])
    ax[2,2].set_yticklabels([])
    ax[2,3].set_yticklabels([])
    ax[1,2].set_xticks([])
    ax[1,3].set_xticks([])
    ax[1,1].set_xticks([])
    ax[1,0].set_xticks([])
    ax[1,0].set_xlim([0,200])
    ax[1,1].set_xlim([0,200])
    ax[1,2].set_xlim([0,200])
    ax[1,3].set_xlim([0,200])
    ax[0,0].axis('off')
    plt.savefig(f'/Users/harryclark/Documents/spatial-manifolds/scripts/figures/figure_4_xgboost/example_cell_{mouse}_day{day}_cluster{cluster_id}.pdf', dpi=300, bbox_inches='tight')
    plt.show()
# Out:
# Mouse: 26, Day: 19, Cluster: 24
# hi
# plotting true rate map
# for cell 24, avg pR2 (pos only) is -0.0002849669496088225, using 0 covariate cells
# using expected spikes for cell 18
# for cell 24, avg pR2 is 0.2634076749637166, for medial_MEC, using 70 covariate cells
# using expected spikes for cell 18
# hi
# for cell 24, avg pR2 is 0.044669199233228304, for lateral_MEC, using 147 covariate cells
# using expected spikes for cell 18
# hi
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 320x272 with 12 Axes>
# Mouse: 26, Day: 19, Cluster: 113
# hi
# plotting true rate map
# for cell 113, avg pR2 (pos only) is 0.03996431934223168, using 0 covariate cells
# using expected spikes for cell 18
# for cell 113, avg pR2 is 0.2671125365282336, for medial_MEC, using 70 covariate cells
# using expected spikes for cell 18
# hi
# for cell 113, avg pR2 is 0.08379384570328259, for lateral_MEC, using 147 covariate cells
# using expected spikes for cell 18
# hi
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 320x272 with 12 Axes>
# Mouse: 26, Day: 19, Cluster: 114
# hi
# plotting true rate map
# for cell 114, avg pR2 (pos only) is 0.11721116653306855, using 0 covariate cells
# using expected spikes for cell 18
# for cell 114, avg pR2 is 0.28651040801390326, for medial_MEC, using 70 covariate cells
# using expected spikes for cell 18
# hi
# for cell 114, avg pR2 is 0.1357534225787053, for lateral_MEC, using 147 covariate cells
# using expected spikes for cell 18
# hi
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 320x272 with 12 Axes>
# Mouse: 26, Day: 19, Cluster: 115
# hi
# plotting true rate map
# for cell 115, avg pR2 (pos only) is 0.0001674454782552459, using 0 covariate cells
# using expected spikes for cell 18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hd/t83f2v6s1vv8wtlhdtp13t4m0000gn/T/ipykernel_56862/1630501170.py in ?()
#      77     X_posonly = pos_in_time.reshape(-1, 1)
#      78     Y_hat_pos, pR2_cv_pos = xgb_history.fit_cv(X_posonly, target_fr, verbose=0, continuous_folds=True)
#      79     print(f'for cell {cluster_id}, avg pR2 (pos only) is {np.nanmean(pR2_cv_pos)}, using 0 covariate cells')
#      80     expected_spikes_pos = {ns.cluster_id.values[0]: Y_hat_pos}
# ---> 81     tcs_expected_spikes_pos, _, _ , last_ephys_bin, beh, _ = compute_vr_tcs_using_expected_spikes(
#      82         mouse, day, apply_zscore=False, apply_guassian_filter=False, vr_type='VR', source_path=source_path, expected_spikes=expected_spikes_pos)
#      83     tc_es_pos = tcs_expected_spikes_pos[ns.cluster_id.values[0]]
#      84     tc_es_pos = gaussian_filter(np.nan_to_num(tc_es_pos).astype(np.float64), sigma=2.5)
#
# ~/Documents/spatial-manifolds/src/spatial_manifolds/detect_grids.py in ?(mouse, day, apply_zscore, apply_guassian_filter, source_path, bs_t, vr_type, expected_spikes)
#     866                 tc_offset = np.roll(tc, lag)
#     867                 tc_offset[:lag] = 0
#     868             else:
#     869                 tc_offset = tc
# --> 870             corr = stats.pearsonr(tc, tc_offset)[0]
#     871             autocorr.append(corr)
#     872         autocorr = np.array(autocorr)
#     873         autocorrs[cell] = autocorr
#
# /opt/anaconda3/envs/sm/lib/python3.11/site-packages/scipy/stats/_stats_py.py in ?(x, y, alternative, method, axis)
#    4627     # [-5e210, 5e210, 3e200, -3e200]
#    4628     # but not when `axis` is provided, so scale manually. scipy.linalg.norm
#    4629     # also raises an error with NaN input rather than returning NaN, so
#    4630     # use np.linalg.norm.
# -> 4631     xmax = xp.max(xp.abs(xm), axis=axis, keepdims=True)
#    4632     ymax = xp.max(xp.abs(ym), axis=axis, keepdims=True)
#    4633     with np.errstate(invalid='ignore', divide='ignore'):
#    4634         normxm = xmax * xp_vector_norm(xm/xmax, axis=axis, keepdims=True)
#
# KeyboardInterrupt:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 320x272 with 12 Axes>

# %%
# For each good example cell, reconstruct firing rate profiles using xgboost predictions
# You will need to fill in the details for loading tcs_time, pos_in_time, and MLencoding setup

# set up xgboost history model
xgb_history = MLencoding(tunemodel='xgboost', cov_history=True, spike_history=False,
                            window=time_bs, n_filters=5, max_time=1000)

filtered_good_examples = [(25,25,91), (25,25,235)]
for mouse, day, cluster_id in filtered_good_examples:
    print(f"\nMouse: {mouse}, Day: {day}, Cluster: {cluster_id}")
    gcs, ngs, ns, sc, ngs_ns, all = cell_classification_of1(mouse, day, percentile_threshold=95, verbose=False) # subset
    tcs, tcs_time, _, last_ephys_bin, beh, clusters = compute_vr_tcs(mouse,day, apply_zscore=False, apply_guassian_filter=False)
    last_ephys_time_bin = clusters[clusters.index[0]].count(bin_size=time_bs, time_units = 'ms').index[-1]

    gcs = reconstruct_shank_id(gcs)
    ngs = reconstruct_shank_id(ngs)
    # time binned variables for later
    ep = nap.IntervalSet(start=0, end=last_ephys_time_bin, time_units = 's')
    speed_in_time = np.array(beh['S'].bin_average(bin_size=time_bs, time_units = 'ms', ep=ep))
    dt_in_time = np.array(beh['travel'].bin_average(bin_size=time_bs, time_units = 'ms', ep=ep)-((beh['trial_number'][0]-1)*tl))
    pos_in_time = dt_in_time%tl
    trial_number_in_time = (dt_in_time//tl)+beh['trial_number'][0]

    if np.any(np.isnan(pos_in_time)):
        series = pd.Series(dt_in_time)
        filled_series = series.ffill().bfill()
        dt_in_time = np.array(filled_series)
        pos_in_time = dt_in_time%tl
        trial_number_in_time = (dt_in_time//tl)+beh['trial_number'][0]

    if np.any(np.isnan(speed_in_time)):
        series = pd.Series(speed_in_time)
        filled_series = series.ffill().bfill()
        speed_in_time = np.array(filled_series)

    # Get the target cell's firing rate
    target_fr = tcs_time[cluster_id]

    locations = pd.read_csv(f'{source_path}/all_cluster_brain_locations_chris.csv')
    locations = locations[(locations['mouse'] == mouse) & (locations['day'] == day)]
    locations['coord_SCs_x'] = locations['coord_SCs_x'] * -1  # correct for the flipped SCs x coordinates

    # Set up 4-column plot: True, Pos-only, Medial, Lateral
    fig, ax = plt.subplots(ncols=4, nrows=3, figsize=(rm_figsize[0]*3.2, rm_figsize[1]*1.7), 
                           sharex=False, sharey='row', height_ratios=[0.6, 0.25, 1], width_ratios=[1,1,1,1])
    plt.subplots_adjust(wspace=0.38, hspace=0.35)

    # --- Annotation plot above Pos-only column (no cells highlighted) ---
    annotations, annotation_colors, xs, ys = make_annotations(mouse, path='/Users/harryclark/Documents/spatial-manifolds/data')
    unique_colors = np.unique(annotation_colors)
    for color_ in unique_colors:
        border_points = extract_border(annotation_colors, color_, only_border=False)
        x_points = xs[border_points[:, 1]]
        y_points = ys[border_points[:, 0]]
        ax[0,1].scatter(x_points, y_points, color=color_, s=1, label=color_, rasterized=True)
    plot_NP2_probe(ax[0,1], sorting_analyzer_path='/Users/harryclark/Downloads/kilosort4_sa', 
                probe_alpha=0.5, contacts_alpha=0.0, probe_color='grey', probe_edgecolor='black')
    ax[0,1].set_ylim([min_y, max_y])
    ax[0,1].set_xlim([-100, 900])
    ax[0,1].spines['top'].set_visible(True)
    ax[0,1].spines['right'].set_visible(True)
    ax[0,1].spines['bottom'].set_visible(True)
    ax[0,1].spines['left'].set_visible(True)

    # --- True rate map ---
    tc = tcs[cluster_id]
    tc = gaussian_filter(np.nan_to_num(tc).astype(np.float64), sigma=2.5)
    tc = tc[:last_ephys_bin] # only want bins with ephys data in it
    tcz = zscore(tc)
    print(f'plotting true rate map')
    plot_firing_rate_map(ax[2,0], tc, bs=bs, tl=tl, p=95, sort_indices=None, cmap=white_to_hex_cmap('#69201a'))
    ax[1,0].set_title('True', fontsize=5)

    # --- Position-only (n=0) reconstruction ---
    X_posonly = pos_in_time.reshape(-1, 1)
    Y_hat_pos, pR2_cv_pos = xgb_history.fit_cv(X_posonly, target_fr, verbose=0, continuous_folds=True)
    print(f'for cell {cluster_id}, avg pR2 (pos only) is {np.nanmean(pR2_cv_pos)}, using 0 covariate cells')
    expected_spikes_pos = {ns.cluster_id.values[0]: Y_hat_pos}
    tcs_expected_spikes_pos, _, _ , last_ephys_bin, beh, _ = compute_vr_tcs_using_expected_spikes(
        mouse, day, apply_zscore=False, apply_guassian_filter=False, vr_type='VR', source_path=source_path, expected_spikes=expected_spikes_pos)
    tc_es_pos = tcs_expected_spikes_pos[ns.cluster_id.values[0]]
    tc_es_pos = gaussian_filter(np.nan_to_num(tc_es_pos).astype(np.float64), sigma=2.5)
    tc_es_pos = tc_es_pos[:last_ephys_bin]
    plot_firing_rate_map(ax[2,1], tc_es_pos, bs=bs, tl=tl, p=95, sort_indices=None, cmap=white_to_hex_cmap('#69201a'))
    ax[1,1].set_title(f'Pos only (n=0)\npr²: {np.nanmean(pR2_cv_pos):.2f}', fontsize=5)

    # Plot average firing rate profile for Pos only
    trial_groups, trial_colors = get_trial_groups_and_colors(beh, last_ephys_bin, tl, bs, ignore_performance=True)
    for group in np.unique(trial_groups):
        if len(trial_groups[trial_groups == group]) > 5:
            x, y = get_avg_profile(tc_es_pos, bs, tl, mask=trial_groups==group)
            ax[1,1].plot(x, y, color=trial_colors[trial_groups==group][0], linewidth=1)
    # Only allow max two y ticks on 2nd row
    for col in range(4):
        ax[1,col].yaxis.set_major_locator(plt.MaxNLocator(nbins=2, integer=True))
    # Remove axis from 1st row, 2nd column only
    ax[0,1].axis('off')

    # --- Medial and Lateral reconstructions ---
    tidy_labels = {'medial_MEC': 'P + mNGS', 'lateral_MEC': 'P + lNGS'}
    for cov_idx, cov_label in enumerate(['medial_MEC', 'lateral_MEC']):
        # Get covariate NGS cluster_ids in the correct ML bin
        cov_bounds = (-np.inf, 3400) if cov_label == 'medial_MEC' else (3400, np.inf)
        covariate_cluster_ids = ngs.cluster_id.values.astype(int)
        covariate_cluster_ids = covariate_cluster_ids[
            np.isin(
                covariate_cluster_ids,
                locations[
                    (locations['coord_SCs_x'] >= cov_bounds[0]) &
                    (locations['coord_SCs_x'] < cov_bounds[1])
                ]['cluster_id'].values.astype(int)
            )
        ]

        # Build covariate matrix X (n_timepoints x n_covariate_cells)
        cov_tcs_time = {cid: tcs_time[cid] for cid in covariate_cluster_ids if cid in tcs_time}
        if len(cov_tcs_time) == 0:
            print(f"No covariate cells found for {cov_label}")
            continue
        X = np.vstack(list(cov_tcs_time.values())).T
        X = np.column_stack((pos_in_time, X))
        n_cov_cells = len(X.T)-1 # subtract 1 for position
        Y_hat, pR2_cv = xgb_history.fit_cv(X, target_fr, verbose=0, continuous_folds=True)
        print(f'for cell {cluster_id}, avg pR2 is {np.nanmean(pR2_cv)}, for {cov_label}, using {n_cov_cells} covariate cells')
        expected_spikes = {ns.cluster_id.values[0]: Y_hat}
        tcs_expected_spikes, _, _ , last_ephys_bin, beh, _ = compute_vr_tcs_using_expected_spikes(
            mouse, day, apply_zscore=False, apply_guassian_filter=False, vr_type='VR', source_path=source_path, expected_spikes=expected_spikes)
        tc_es = tcs_expected_spikes[ns.cluster_id.values[0]]
        tc_es = gaussian_filter(np.nan_to_num(tc_es).astype(np.float64), sigma=2.5)
        tc_es = tc_es[:last_ephys_bin]
        plot_firing_rate_map(ax[2,cov_idx+2], tc_es, bs=bs, tl=tl, p=95, sort_indices=None, cmap=white_to_hex_cmap('#69201a'))
        ax[1,cov_idx+2].set_title(f'{tidy_labels[cov_label]} (n={n_cov_cells})\npr²: {np.nanmean(pR2_cv):.2f}', fontsize=5)

        # Plot trial-averaged profiles for each group
        for group in np.unique(trial_groups):
            if len(trial_groups[trial_groups == group]) > 5:
                x, y = get_avg_profile(tc, bs, tl, mask=trial_groups==group)
                if cov_idx == 0:
                    ax[1,0].plot(x, y, color=trial_colors[trial_groups==group][0], linewidth=1)
                x, y = get_avg_profile(tc_es, bs, tl, mask=trial_groups==group)
                ax[1,cov_idx+2].plot(x, y, color=trial_colors[trial_groups==group][0], linewidth=1)

        # Plot probe locations and cell highlights for each covariate column
        annotations, annotation_colors, xs, ys = make_annotations(mouse, path='/Users/harryclark/Documents/spatial-manifolds/data')
        unique_colors = np.unique(annotation_colors)
        for color_ in unique_colors:
            border_points = extract_border(annotation_colors, color_, only_border=False)
            x_points = xs[border_points[:, 1]]
            y_points = ys[border_points[:, 0]]
            ax[0,cov_idx+2].scatter(x_points, y_points, color=color_, s=1, label=color_, rasterized=True)
        plot_NP2_probe(ax[0,cov_idx+2], sorting_analyzer_path='/Users/harryclark/Downloads/kilosort4_sa', 
                    probe_alpha=0.5, contacts_alpha=0.0, probe_color='grey', probe_edgecolor='black')
        ax[0,cov_idx+2].scatter(ngs.probe_x.values, ngs.probe_y.values, marker='o', color="grey", alpha=0.4, s=7)
        ax[0,cov_idx+2].scatter(gcs.probe_x.values, gcs.probe_y.values, marker='o', color="grey", alpha=0.4, s=7)
        min_y = min(all['probe_y'].values) - 300
        max_y = max(all['probe_y'].values) + 300
        target_id = cluster_id
        target_row = all[all['cluster_id'] == target_id]
        # Move star scatter after all other scatter points for highest zorder
        if not target_row.empty:
            x_t, y_t = target_row['probe_x'].values[0], target_row['probe_y'].values[0]
            ax[0,cov_idx+2].scatter(x_t, y_t, marker='*', s=120, color='white', edgecolor='black', linewidth=0.7, zorder=100)
        cov_row = all[np.isin(all['cluster_id'], covariate_cluster_ids)]
        if not cov_row.empty:
            for _, row in cov_row.iterrows():
                x_c, y_c = row['probe_x'], row['probe_y']
                from matplotlib.patches import Circle
                circ2 = Circle((x_c, y_c), radius=20, edgecolor='#0d2958', facecolor='#0d2958', lw=2, alpha=0.6, zorder=12)
                ax[0,cov_idx+2].add_patch(circ2)
        ax[0,cov_idx+2].set_ylim([min_y, max_y])
        ax[0,cov_idx+2].set_xlim([-100, 900])
        ax[0,cov_idx+2].spines['top'].set_visible(True)
        ax[0,cov_idx+2].spines['right'].set_visible(True)
        ax[0,cov_idx+2].spines['bottom'].set_visible(True)
        ax[0,cov_idx+2].spines['left'].set_visible(True)

    # Set axis labels and hide unused axes
    ax[2,0].set_xlabel('Pos (cm)')
    ax[2,1].set_xlabel('Pos (cm)')
    ax[2,2].set_xlabel('Pos (cm)')
    ax[2,3].set_xlabel('Pos (cm)')
    # Only show y tick labels on the 3rd row, 1st column
    ax[2,1].set_yticklabels([])
    ax[2,2].set_yticklabels([])
    ax[2,3].set_yticklabels([])
    ax[1,2].set_xticks([])
    ax[1,3].set_xticks([])
    ax[1,1].set_xticks([])
    ax[1,0].set_xticks([])
    ax[1,0].set_xlim([0,200])
    ax[1,1].set_xlim([0,200])
    ax[1,2].set_xlim([0,200])
    ax[1,3].set_xlim([0,200])
    ax[0,0].axis('off')
    plt.savefig(f'/Users/harryclark/Documents/spatial-manifolds/scripts/figures/figure_4_xgboost/example_cell_{mouse}_day{day}_cluster{cluster_id}.pdf', dpi=300, bbox_inches='tight')
    plt.show()
# Out:
# Mouse: 25, Day: 25, Cluster: 91
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 11
#       9 for mouse, day, cluster_id in filtered_good_examples:
#      10     print(f"\nMouse: {mouse}, Day: {day}, Cluster: {cluster_id}")
# ---> 11     gcs, ngs, ns, sc, ngs_ns, all = cell_classification_of1(mouse, day, percentile_threshold=95, verbose=False) # subset
#      12     tcs, tcs_time, _, last_ephys_bin, beh, clusters = compute_vr_tcs(mouse,day, apply_zscore=False, apply_guassian_filter=False)
#      13     last_ephys_time_bin = clusters[clusters.index[0]].count(bin_size=time_bs, time_units = 'ms').index[-1]
#
# File ~/Documents/spatial-manifolds/src/spatial_manifolds/detect_grids.py:252, in cell_classification_of1(mouse, day, percentile_threshold, source_path, disqualifying_brain_areas_for_grid_cells, disqualifying_brain_areas_for_spatial_cells, use_optimal_travel, get_extra_info, verbose, session)
#     250 if source_path is None:
#     251     source_path = '/Users/harryclark/Downloads/COHORT12/'
# --> 252 _,_,_,_,_,clusters_VR = compute_vr_tcs(mouse, day, source_path=source_path)
#     253 last_ephys_time_bin = clusters_VR[clusters_VR.index[0]].count(bin_size=time_bs, time_units = 'ms').index[-1]
#     255 brain_locations = pd.read_csv(source_path+'all_cluster_brain_locations_chris.csv')
#
# File ~/Documents/spatial-manifolds/src/spatial_manifolds/detect_grids.py:1109, in compute_vr_tcs(mouse, day, apply_zscore, apply_guassian_filter, source_path, bs_t, vr_type)
#    1107     else:
#    1108         tc_offset = tc
# -> 1109     corr = stats.pearsonr(tc, tc_offset)[0]
#    1110     autocorr.append(corr)
#    1111 autocorr = np.array(autocorr)
#
# File /opt/anaconda3/envs/sm/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4579, in pearsonr(x, y, alternative, method, axis)
#    4577 # If an input is constant, the correlation coefficient is not defined.
#    4578 const_x = xp.all(x == x[..., 0:1], axis=-1)
# -> 4579 const_y = xp.all(y == y[..., 0:1], axis=-1)
#    4580 const_xy = const_x | const_y
#    4581 if xp.any(const_xy):
#
# File /opt/anaconda3/envs/sm/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:2606, in _all_dispatcher(a, axis, out, keepdims, where)
#    2498     """
#    2499     Test whether any array element along a given axis evaluates to True.
#    2500
#    (...)   2600
#    2601     """
#    2602     return _wrapreduction_any_all(a, np.logical_or, 'any', axis, out,
#    2603                                   keepdims=keepdims, where=where)
# -> 2606 def _all_dispatcher(a, axis=None, out=None, keepdims=None, *,
#    2607                     where=None):
#    2608     return (a, where, out)
#    2611 @array_function_dispatch(_all_dispatcher)
#    2612 def all(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import pandas as pd

# Define two shades of red
red_palette = ["#c04744", "#c04744"]

for pos_in_cov in [True, False]:
    data_ = data[data['include_position'] == pos_in_cov]

    labels = list(data_['covariate_pos_label'].unique())
    fig, axes = plt.subplots(1, 2, figsize=(8, 3), sharey=True)

    x_bins = np.arange(2900, 3900, 100)
    x_centers = 0.5 * (x_bins[:-1] + x_bins[1:])

    for i, (label, color) in enumerate(zip(labels, red_palette)):
        ax = axes[i]
        subset = data_[data_['covariate_pos_label'] == label].copy()
        sns.scatterplot(
            data=subset,
            x='coord_SCs_x',
            y='pR2_cv',
            color=color,
            alpha=0.7,
            ax=ax
        )

        subset['mouse_day'] = subset['mouse'].astype(str) + '_' + subset['day'].astype(str)
        subset['mouse_day_cluster'] = subset['mouse_day'] + '_' + subset['target_cluster_id'].astype(str)
        model = smf.mixedlm(
            "pR2_cv ~ coord_SCs_x + n_covariate_cells",
            subset,
            groups=subset["mouse"],
            re_formula="1",
            vc_formula={
                "mouse_day": "0 + C(mouse_day)",
                "mouse_day_cluster": "0 + C(mouse_day_cluster)"
            }
        )
        result = model.fit()
        print(result.summary())
        intercept = result.params['Intercept']
        slope = result.params['coord_SCs_x']
        cov_cells_effect = result.params.get('n_covariate_cells', 0)
        mean_cov_cells = subset['n_covariate_cells'].mean()
        y_fit = intercept + slope * x_centers + cov_cells_effect * mean_cov_cells

        # Bin SEM calculation (fixed bin edges)
        sems = []
        for j in range(len(x_bins)-1):
            bin_mask = (subset['coord_SCs_x'] >= x_bins[j]) & (subset['coord_SCs_x'] < x_bins[j+1])
            bin_sem = subset.loc[bin_mask, 'pR2_cv'].sem()
            sems.append(bin_sem if not np.isnan(bin_sem) else 0)
        sems = np.array(sems)

        ax.plot(x_centers, y_fit, color=color, label=f'LMM fit', linewidth=2)
        ax.fill_between(x_centers, y_fit - sems, y_fit + sems, color=color, alpha=0.2)

        # Annotate p-value at the rightmost part of the fit line
        pval = result.pvalues.get('coord_SCs_x', None)
        if pval is not None:
            y_annot = y_fit[-1] + sems[-1] + 0.01
            ax.text(x_centers[-1], y_annot, f'p={pval:.2g}', color=color, fontsize=12, ha='right', va='bottom', fontweight='bold')

        ax.set_xlim(2900, 3800)
        ax.axvline(3400, linestyle='dashed', color='black')
        ax.set_xlabel('Medial-lateral (μm)')
        if i == 0:
            ax.set_ylabel('Grid cell pR²')
        fig.tight_layout()

        if pos_in_cov:
            ax.set_title(f'Covariate: P + {label}')
            plt.savefig('/Users/harryclark/Documents/spatial-manifolds/scripts/figures/figure_4_xgboost/absolute_pr2_grid_cells_split_pos.pdf')
        else:
            ax.set_title(f'Covariate: {label}')
            plt.savefig('/Users/harryclark/Documents/spatial-manifolds/scripts/figures/figure_4_xgboost/absolute_pr2_grid_cells_split_no_pos.pdf')
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import pandas as pd

# Calculate pR2 difference for each unique group
group_cols = ['target_cluster_id', 'covariate_pos_label', 'mouse', 'day']
df_true = data[data['include_position'] == True].copy()
df_false = data[data['include_position'] == False].copy()

# Merge on group_cols to align True/False rows
merged = pd.merge(
    df_true[group_cols + ['pR2_cv', 'coord_SCs_x', 'n_covariate_cells']],
    df_false[group_cols + ['pR2_cv']],
    on=group_cols,
    suffixes=('_true', '_false')
 )
merged['pR2_diff'] = merged['pR2_cv_true'] - merged['pR2_cv_false']

# Plot on two subplots, one for each covariate_pos_label
red_palette = ["#c04744", "#69201a"]
labels = list(merged['covariate_pos_label'].unique())
fig, axes = plt.subplots(1, 2, figsize=(8, 3), sharey=True)
x_bins = np.arange(2900, 3900, 100)
x_centers = 0.5 * (x_bins[:-1] + x_bins[1:])

for i, (label, color) in enumerate(zip(labels, red_palette)):
    ax = axes[i]
    subset = merged[merged['covariate_pos_label'] == label].copy()
    sns.scatterplot(
        data=subset,
        x='coord_SCs_x',
        y='pR2_diff',
        color=color,
        alpha=0.7,
        ax=ax
    )

    subset['mouse_day'] = subset['mouse'].astype(str) + '_' + subset['day'].astype(str)
    subset['mouse_day_cluster'] = subset['mouse_day'] + '_' + subset['target_cluster_id'].astype(str)
    if len(subset) > 0:
        model = smf.mixedlm(
            "pR2_diff ~ coord_SCs_x + n_covariate_cells",
            subset,
            groups=subset["mouse"],
            re_formula="1",
            vc_formula={
                "mouse_day": "0 + C(mouse_day)",
                "mouse_day_cluster": "0 + C(mouse_day_cluster)"
            }
        )
        result = model.fit()
        print(result.summary())
        intercept = result.params['Intercept']
        slope = result.params['coord_SCs_x']
        cov_cells_effect = result.params.get('n_covariate_cells', 0)
        mean_cov_cells = subset['n_covariate_cells'].mean()
        y_fit = intercept + slope * x_centers + cov_cells_effect * mean_cov_cells

        # Bin SEM calculation (fixed bin edges)
        sems = []
        for j in range(len(x_bins)-1):
            bin_mask = (subset['coord_SCs_x'] >= x_bins[j]) & (subset['coord_SCs_x'] < x_bins[j+1])
            bin_sem = subset.loc[bin_mask, 'pR2_diff'].sem()
            sems.append(bin_sem if not np.isnan(bin_sem) else 0)
        sems = np.array(sems)

        ax.plot(x_centers, y_fit, color=color, label=f'LMM fit', linewidth=2)
        ax.fill_between(x_centers, y_fit - sems, y_fit + sems, color=color, alpha=0.2)

        # Annotate p-value at the rightmost part of the fit line
        pval = result.pvalues.get('coord_SCs_x', None)
        if pval is not None:
            y_annot = y_fit[-1] + sems[-1] + 0.01
            ax.text(x_centers[-1], y_annot, f'p={pval:.2g}', color=color, fontsize=12, ha='right', va='bottom', fontweight='bold')

    ax.set_xlim(2900, 3800)
    ax.set_xlabel('Medial-lateral (μm)')
    if i == 0:
        ax.set_ylabel('Δ Grid cell pR² (Included - Not Included)')
    ax.set_title(label)

fig.tight_layout()
plt.savefig('/Users/harryclark/Documents/spatial-manifolds/scripts/figures/figure_4_xgboost/absolute_pr2_grid_cells_diff_inclusion_subplots.pdf')
plt.show()
# Out:
#              Mixed Linear Model Regression Results
# ================================================================
# Model:                MixedLM    Dependent Variable:    pR2_diff
# No. Observations:     770        Method:                REML
# No. Groups:           8          Scale:                 0.0045
# Min. group size:      2          Log-Likelihood:        908.2294
# Max. group size:      204        Converged:             No
# Mean group size:      96.2
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept             -0.297    0.074 -4.013 0.000 -0.442 -0.152
# coord_SCs_x            0.000    0.000  3.439 0.001  0.000  0.000
# n_covariate_cells      0.001    0.000 15.166 0.000  0.001  0.001
# Group Var              0.004
# mouse_day Var          0.004
# mouse_day_cluster Var  0.000    0.029
# ================================================================
#
#              Mixed Linear Model Regression Results
# ================================================================
# Model:                MixedLM    Dependent Variable:    pR2_diff
# No. Observations:     496        Method:                REML
# No. Groups:           6          Scale:                 0.0010
# Min. group size:      32         Log-Likelihood:        957.5697
# Max. group size:      96         Converged:             No
# Mean group size:      82.7
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              0.051    0.032  1.601 0.109 -0.011  0.113
# coord_SCs_x           -0.000    0.000 -2.622 0.009 -0.000 -0.000
# n_covariate_cells      0.000    0.000 11.891 0.000  0.000  0.000
# Group Var              0.000    0.003
# mouse_day Var          0.000    0.002
# mouse_day_cluster Var  0.000    0.003
# ================================================================
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x300 with 2 Axes>

# %%
import os
import glob

data_dir = '/Users/harryclark/Downloads/COHORT12/xgboost_task_anchoring'
all_files = glob.glob(os.path.join(data_dir, "*.csv"))

dataX = pd.DataFrame()
for file in all_files:
    df = pd.read_csv(file)

    if 'X_pos_cov' not in df.columns or 'Y_pos_cov' not in df.columns:
        print(f"Skipping file {file} due to missing columns.")
        continue

    dataX = pd.concat([dataX, df], ignore_index=True)

# %%
dataX

# %%
# Combine keys in data and dataX
data['unique_id'] = data['target_cluster_id'].astype(str) + '_' + data['mouse'].astype(str) + '_' + data['day'].astype(str)
dataX['unique_id'] = dataX['cluster_id'].astype(str) + '_' + dataX['mouse'].astype(str) + '_' + dataX['day'].astype(str)

# Find n_neurons==0 for each unique_id in dataX
dataX= dataX[dataX['n_neurons'] == 0]

# %%
data

# %%
# Get unique rows from data based on unique_id
unique_rows = data.drop_duplicates(subset=['unique_id'])[['target_cluster_id', 'mouse', 'day', 'unique_id']]

# Filter dataX for n_neurons == 0
dataX_0 = dataX[dataX['n_neurons'] == 0].copy()
dataX_0 = dataX_0.drop_duplicates(subset=['unique_id'])[['cluster_id', 'mouse', 'day', 'unique_id', 'pR2_cv', 'tested_on']]
dataX_0 = dataX_0[(dataX_0['tested_on'] == 'ncmGC') | 
                  (dataX_0['tested_on'] == 'cmGC') |
                  (dataX_0['tested_on'] == 'GC')]
dataX_0

# %%
dataX_0

# %%
# NGS trial-by-position rate maps, ordered by individual ΔpR² = (P+cells) - (P)
# Layout: medial cells first, then a blank separator row, then lateral cells.

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
good_mouse = 25
good_day = 25

gcs, ngs, all = classify_
plot_mouse = good_mouse if 'good_mouse' in globals() else int(data['mouse'].iloc[0])
plot_day = good_day if 'good_day' in globals() else int(data['day'].iloc[0])

# ---- Build per-cell ordering metric from precomputed table ----
# Restrict to NGS targets for this session.
ng_df = data[
    (data['mouse'].astype(int) == int(plot_mouse)) &
    (data['day'].astype(int) == int(plot_day)) &
    (data['target_cell_type'].astype(str).isin(['NG', 'NGS']))
].copy()

if ng_df.empty:
    raise ValueError(f'No NGS rows found in data for M{plot_mouse} D{plot_day}.')

# Baseline P model: include_position=True and n_covariate_cells==0
pos_df = ng_df[
    (ng_df['include_position'] == True) &
    (ng_df['n_covariate_cells'].fillna(0) == 0)
][['target_cluster_id', 'pR2_cv']].drop_duplicates(subset=['target_cluster_id'])
pos_df = pos_df.rename(columns={'pR2_cv': 'pR2_pos'})

# P+cells models: include_position=True and covariates present
cov_df = ng_df[
    (ng_df['include_position'] == True) &
    (ng_df['n_covariate_cells'].fillna(0) > 0)
].copy()

# Normalize target and covariate labels to medial/lateral
def _norm_ml(label):
    s = str(label).lower()
    if 'medial' in s:
        return 'medial'
    if 'lateral' in s:
        return 'lateral'
    return np.nan

cov_df['target_group'] = cov_df['target_pos_label'].apply(_norm_ml)
cov_df['cov_group'] = cov_df['covariate_pos_label'].apply(_norm_ml)

# Keep only rows where covariate group matches target group,
# then pick best available pR² per target for robust sorting.
match_df = cov_df[cov_df['target_group'] == cov_df['cov_group']].copy()
match_df = (
    match_df.sort_values('pR2_cv', ascending=False)
    .drop_duplicates(subset=['target_cluster_id'])
)

metric_df = match_df[['target_cluster_id', 'target_group', 'pR2_cv']].rename(columns={'pR2_cv': 'pR2_pos_cells'})
metric_df = metric_df.merge(pos_df, on='target_cluster_id', how='left')
metric_df = metric_df.dropna(subset=['pR2_pos'])
metric_df['delta_pr2'] = metric_df['pR2_pos_cells'] - metric_df['pR2_pos']

# Sort within each group by individual ΔpR² (descending)
medial_cells = (
    metric_df[metric_df['target_group'] == 'medial']
    .sort_values('delta_pr2', ascending=False)
)
lateral_cells = (
    metric_df[metric_df['target_group'] == 'lateral']
    .sort_values('delta_pr2', ascending=False)
)

medial_ids = medial_cells['target_cluster_id'].astype(int).tolist()
lateral_ids = lateral_cells['target_cluster_id'].astype(int).tolist()

if len(medial_ids) + len(lateral_ids) == 0:
    raise ValueError('No NGS cells with valid ΔpR² ordering metric were found.')

# ---- Load session traces and build trial-by-position maps ----
tcs, tcs_time, _, _, beh, clusters = compute_vr_tcs(
    plot_mouse,
    plot_day,
    apply_zscore=False,
    apply_guassian_filter=False,
)

last_ephys_time_bin = clusters[clusters.index[0]].count(bin_size=time_bs, time_units='ms').index[-1]
ep = nap.IntervalSet(start=0, end=last_ephys_time_bin, time_units='s')

dt_in_time = np.array(
    beh['travel'].bin_average(bin_size=time_bs, time_units='ms', ep=ep)
    - ((beh['trial_number'][0] - 1) * tl)
)
pos_in_time = dt_in_time % tl
trial_number_in_time = (dt_in_time // tl) + beh['trial_number'][0]

if np.any(np.isnan(pos_in_time)):
    dt_in_time = np.array(pd.Series(dt_in_time).ffill().bfill())
    pos_in_time = dt_in_time % tl
    trial_number_in_time = (dt_in_time // tl) + beh['trial_number'][0]

n_pos_bins = int(np.ceil(tl / bs))

def build_trial_position_map(spikes_t, pos_t, trial_t, n_bins):
    trial_ids = np.unique(trial_t.astype(int))
    mat = np.full((len(trial_ids), n_bins), np.nan)

    pbin = np.floor(np.clip(pos_t, 0, tl - 1e-9) / bs).astype(int)
    pbin = np.clip(pbin, 0, n_bins - 1)

    for i, tr in enumerate(trial_ids):
        m = trial_t.astype(int) == tr
        if not np.any(m):
            continue
        sums = np.bincount(pbin[m], weights=spikes_t[m], minlength=n_bins)
        counts = np.bincount(pbin[m], minlength=n_bins)
        with np.errstate(divide='ignore', invalid='ignore'):
            mat[i] = sums / counts
        mat[i, counts == 0] = np.nan
    return mat, trial_ids

cell_maps = {}
for cid in medial_ids + lateral_ids:
    if cid not in tcs_time:
        continue
    y = np.asarray(tcs_time[cid])
    T = len(y)
    p = pos_in_time[:T]
    tr = trial_number_in_time[:T]
    m, tr_ids = build_trial_position_map(y, p, tr, n_pos_bins)
    cell_maps[cid] = m

medial_ids = [cid for cid in medial_ids if cid in cell_maps]
lateral_ids = [cid for cid in lateral_ids if cid in cell_maps]

# ---- Figure layout ----
# 5 content rows total, split between medial and lateral, with 1 separator row.
content_rows = 5
gap_rows = 1

total_cells = len(medial_ids) + len(lateral_ids)
if total_cells == 0:
    raise ValueError('No NGS cells available in tcs_time for plotting.')

medial_row_count = int(np.clip(np.round(content_rows * len(medial_ids) / total_cells), 1, content_rows - 1))
lateral_row_count = content_rows - medial_row_count

n_cols = max(
    1,
    int(math.ceil(len(medial_ids) / medial_row_count)) if len(medial_ids) > 0 else 1,
    int(math.ceil(len(lateral_ids) / lateral_row_count)) if len(lateral_ids) > 0 else 1,
)

n_rows_total = medial_row_count + gap_rows + lateral_row_count
fig, axes = plt.subplots(
    nrows=n_rows_total,
    ncols=n_cols,
    figsize=(n_cols * 1.5, n_rows_total * 1.3),
    sharex=False,
    sharey=False,
)
if n_rows_total == 1 and n_cols == 1:
    axes = np.array([[axes]])
elif n_rows_total == 1:
    axes = np.array([axes])
elif n_cols == 1:
    axes = np.array([[ax] for ax in axes])

# consistent color scale across all maps
all_vals = np.concatenate([
    np.ravel(m[np.isfinite(m)]) for m in cell_maps.values() if np.any(np.isfinite(m))
])
vmin = np.nanpercentile(all_vals, 5) if len(all_vals) else 0
vmax = np.nanpercentile(all_vals, 95) if len(all_vals) else 1

# turn everything off first
for r in range(n_rows_total):
    for c in range(n_cols):
        axes[r, c].axis('off')

# helper to place one group row-major in designated row range
def _plot_group(ids, start_row, n_rows_group, title_prefix):
    for k, cid in enumerate(ids):
        rr = k // n_cols
        cc = k % n_cols
        if rr >= n_rows_group:
            break
        ax = axes[start_row + rr, cc]
        m = cell_maps[cid]
        im = ax.imshow(m, aspect='auto', origin='lower', cmap='magma', vmin=vmin, vmax=vmax)
        dval = metric_df.loc[metric_df['target_cluster_id'] == cid, 'delta_pr2']
        dtxt = float(dval.iloc[0]) if len(dval) else np.nan
        ax.set_title(f'C{cid}  ΔpR²={dtxt:.3f}', fontsize=6)
        ax.set_xticks([])
        ax.set_yticks([])
        ax.axis('on')
        for spine in ax.spines.values():
            spine.set_visible(False)

_plot_group(medial_ids, 0, medial_row_count, 'Medial')

# separator row (left blank, with label)
sep_row = medial_row_count
for c in range(n_cols):
    axes[sep_row, c].axis('off')
if n_cols > 0:
    axes[sep_row, 0].text(0.0, 0.5, '--- separator ---', transform=axes[sep_row, 0].transAxes,
                          ha='left', va='center', fontsize=8, color='gray')

_plot_group(lateral_ids, medial_row_count + gap_rows, lateral_row_count, 'Lateral')

# section headers
fig.text(0.01, 0.98, f'Medial NGS (n={len(medial_ids)})', ha='left', va='top', fontsize=11, fontweight='bold')
fig.text(0.01, 0.50, f'Lateral NGS (n={len(lateral_ids)})', ha='left', va='top', fontsize=11, fontweight='bold')
fig.suptitle(f'NGS Trial-by-Position Maps  M{plot_mouse} D{plot_day}\nSorted within group by individual ΔpR² = (P+cells) - (P)', y=0.995, fontsize=11)

# shared colorbar
mappable = plt.cm.ScalarMappable(cmap='magma')
mappable.set_clim(vmin, vmax)
cbar = fig.colorbar(mappable, ax=axes.ravel().tolist(), fraction=0.015, pad=0.01)
cbar.set_label('Firing rate (a.u.)', fontsize=9)

plt.tight_layout(rect=[0, 0, 0.98, 0.97])
plt.savefig(
    f'/Users/harryclark/Documents/spatial-manifolds/scripts/figures/figure_4_xgboost/'
    f'ngs_trial_position_grid_M{plot_mouse}_D{plot_day}_medial_then_lateral.pdf',
    dpi=300,
    bbox_inches='tight'
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 24
#      17 ng_df = data[
#      18     (data['mouse'].astype(int) == int(plot_mouse)) &
#      19     (data['day'].astype(int) == int(plot_day)) &
#      20     (data['target_cell_type'].astype(str).isin(['NG', 'NGS']))
#      21 ].copy()
#      23 if ng_df.empty:
# ---> 24     raise ValueError(f'No NGS rows found in data for M{plot_mouse} D{plot_day}.')
#      26 # Baseline P model: include_position=True and n_covariate_cells==0
#      27 pos_df = ng_df[
#      28     (ng_df['include_position'] == True) &
#      29     (ng_df['n_covariate_cells'].fillna(0) == 0)
#      30 ][['target_cluster_id', 'pR2_cv']].drop_duplicates(subset=['target_cluster_id'])
#
# ValueError: No NGS rows found in data for M25 D25.
